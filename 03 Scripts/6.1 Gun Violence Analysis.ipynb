# %% [markdown]
# # Notebook Contents
# 1. Importing Libraries
# 2. Importing Data
# 3. Data Wrangling Procedures
# 4. Data Consistency Checks
# 5. Exporting Cleaned Dataframe

# %% [markdown]
# # 1. Importing Libraries

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 2. Importing Data

# %%
#Creating path
path =r'C:\Users\smflo\Documents\Gun Violence Analysis'

# %%
#Importing 6.1 Gun Violence Data.csv
df_guns = pd.read_csv(os.path.join(path, '02 Data','Original Data','6.1 Gun Violence Data.csv'), index_col = False)

# %% [markdown]
# # 3. Data Wrangling Procedures

# %%
#Viewing first 5 rows
df_guns.head()
# Out:
#    incident_id      date           state city_or_county  \
# 0       461105  1/1/2013    Pennsylvania     Mckeesport
# 1       460726  1/1/2013      California      Hawthorne
# 2       478855  1/1/2013            Ohio         Lorain
# 3       478925  1/5/2013        Colorado         Aurora
# 4       478959  1/7/2013  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# 2  http://www.gunviolencearchive.org/incident/478855
# ...

# %%
#Checking Shape 
df_guns.shape
# Out:
# (239677, 29)

# %% [markdown]
# ## 3a. Dropping Columns

# %%
#Dropping columns due to not needed for analysis
df_guns= df_guns.drop(columns = ['address', 'incident_url', 'source_url', 'incident_url_fields_missing', 'participant_name', 'sources', 'notes', 'latitude', 'longitude', 'location_description'])

# %%
#Viewing first 5 rows
df_guns.head()
# Out:
#    incident_id      date           state city_or_county  n_killed  n_injured  \
# 0       461105  1/1/2013    Pennsylvania     Mckeesport         0          4
# 1       460726  1/1/2013      California      Hawthorne         1          3
# 2       478855  1/1/2013            Ohio         Lorain         1          3
# 3       478925  1/5/2013        Colorado         Aurora         4          0
# 4       478959  1/7/2013  North Carolina     Greensboro         2          2
#
#    congressional_district              gun_stolen                gun_type  \
# 0                    14.0                     NaN                     NaN
# 1                    43.0                     NaN                     NaN
# 2                     9.0  0::Unknown||1::Unknown  0::Unknown||1::Unknown
# 3                     6.0                     NaN                     NaN
# 4                     6.0  0::Unknown||1::Unknown  0::Handgun||1::Handgun
#
# ...

# %%
#Checking value counts
df_guns['gun_stolen'].value_counts(dropna = False)
# Out:
# 0::Unknown                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            
# ...

# %%
#Checking value counts 
df_guns['gun_type'].value_counts(dropna = False)
# Out:
# NaN                                                                                                                                                                                                                 99451
# 0::Unknown                                                                                                                                                                                                          93559
# 0::Handgun                                                                                                                                                                                                          13018
# 0::9mm                                                                                                                                                                                                               4599
# ...

# %%
#Checking value counts
df_guns['n_guns_involved'].value_counts(dropna = False)
# Out:
# 1.0      127548
# NaN       99451
# 2.0        7477
# 3.0        2021
# 4.0         871
#           ...
# 158.0         1
# 189.0         1
# 85.0          1
# 96.0          1
# 127.0         1
# Name: n_guns_involved, Length: 107, dtype: int64

# %%
#Checking value counts
df_guns['participant_relationship'].value_counts(dropna = False)
# Out:
# NaN                                                                                                                                                                                                                                                                                                                                                                               223903
# 1::Significant others - current or former                                                                                                                                                                                                                                                                                                                                           2651
# ...

# %%
#Dropping columns due to too many missing values
df_guns= df_guns.drop(columns = ['gun_stolen', 'participant_relationship'])

# %%
#Viewing first 5 rows
df_guns.head()
# Out:
#    incident_id      date           state city_or_county  n_killed  n_injured  \
# 0       461105  1/1/2013    Pennsylvania     Mckeesport         0          4
# 1       460726  1/1/2013      California      Hawthorne         1          3
# 2       478855  1/1/2013            Ohio         Lorain         1          3
# 3       478925  1/5/2013        Colorado         Aurora         4          0
# 4       478959  1/7/2013  North Carolina     Greensboro         2          2
#
#    congressional_district                gun_type  \
# 0                    14.0                     NaN
# 1                    43.0                     NaN
# 2                     9.0  0::Unknown||1::Unknown
# 3                     6.0                     NaN
# 4                     6.0  0::Handgun||1::Handgun
#
#                             incident_characteristics  n_guns_involved  \
# 0  Shot - Wounded/Injured||Mass Shooting (4+ vict...              NaN
# ...

# %% [markdown]
# ## 3b. Checking/Changing Data Types

# %%
#Checking descriptive statistics
df_guns.describe()
# Out:
#         incident_id       n_killed      n_injured  congressional_district  \
# count  2.396770e+05  239677.000000  239677.000000           227733.000000
# mean   5.593343e+05       0.252290       0.494007                8.001265
# std    2.931287e+05       0.521779       0.729952                8.480835
# min    9.211400e+04       0.000000       0.000000                0.000000
# 25%    3.085450e+05       0.000000       0.000000                2.000000
# 50%    5.435870e+05       0.000000       0.000000                5.000000
# 75%    8.172280e+05       0.000000       1.000000               10.000000
# max    1.083472e+06      50.000000      53.000000               53.000000
#
#        n_guns_involved  state_house_district  state_senate_district
# count    140226.000000         200905.000000           207342.00000
# mean          1.372442             55.447132               20.47711
# std           4.678202             42.048117               14.20456
# ...

# %%
#Changing data type
df_guns['incident_id'] = df_guns['incident_id'].astype('str')

# %%
#Changing data type
df_guns['congressional_district'] = df_guns['congressional_district'].astype('str')

# %%
#Changing data type
df_guns['state_house_district'] = df_guns['state_house_district'].astype('str')

# %%
#Changing data type
df_guns['state_senate_district'] = df_guns['state_senate_district'].astype('str')

# %%
#Checking descriptive statistics
df_guns.describe()
# Out:
#             n_killed      n_injured  n_guns_involved
# count  239677.000000  239677.000000    140226.000000
# mean        0.252290       0.494007         1.372442
# std         0.521779       0.729952         4.678202
# min         0.000000       0.000000         1.000000
# 25%         0.000000       0.000000         1.000000
# 50%         0.000000       0.000000         1.000000
# 75%         0.000000       1.000000         1.000000
# max        50.000000      53.000000       400.000000

# %% [markdown]
# # 4. Data Consistency Checks

# %% [markdown]
# ## 4a. Mixed Data Types

# %%
#Checking for mixed data types
for col in df_guns.columns.tolist():
  weird = (df_guns[[col]].applymap(type) != df_guns[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_guns[weird]) > 0:
    print (col)
# Out:
# gun_type
# incident_characteristics
# participant_age
# participant_age_group
# participant_gender
# participant_status
# participant_type

# %%
#Changing data type
df_guns['gun_type'] = df_guns['gun_type'].astype('str')

# %%
#Changing data type
df_guns['incident_characteristics'] = df_guns['incident_characteristics'].astype('str')

# %%
#Changing data type
df_guns['participant_age'] = df_guns['participant_age'].astype('str')

# %%
#Changing data type
df_guns['participant_age_group'] = df_guns['participant_age_group'].astype('str')

# %%
#Changing data type
df_guns['participant_gender'] = df_guns['participant_gender'].astype('str')

# %%
#Changing data type
df_guns['participant_status'] = df_guns['participant_status'].astype('str')

# %%
#Changing data type
df_guns['participant_type'] = df_guns['participant_type'].astype('str')

# %% [markdown]
# ## 4b. Missing Values

# %%
#Checking for missing values
df_guns.isnull().sum()
# Out:
# incident_id                     0
# date                            0
# state                           0
# city_or_county                  0
# n_killed                        0
# n_injured                       0
# congressional_district          0
# gun_type                        0
# incident_characteristics        0
# n_guns_involved             99451
# participant_age                 0
# participant_age_group           0
# participant_gender              0
# participant_status              0
# participant_type                0
# state_house_district            0
# state_senate_district           0
# dtype: int64

# %%
#Checking median
df_guns.median()
# Out:
# C:\Users\smflo\AppData\Local\Temp\ipykernel_2920\562998084.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_guns.median()
# incident_id               543587.0
# n_killed                       0.0
# n_injured                      0.0
# congressional_district         5.0
# n_guns_involved                1.0
# state_house_district          47.0
# state_senate_district         19.0
# dtype: float64

# %%
#Imputing missing values with median
df_guns['n_guns_involved']= df_guns['n_guns_involved'].fillna(df_guns['n_guns_involved'].median())

# %%
#Checking for missing values
df_guns.isnull().sum()
# Out:
# incident_id                 0
# date                        0
# state                       0
# city_or_county              0
# n_killed                    0
# n_injured                   0
# congressional_district      0
# gun_type                    0
# incident_characteristics    0
# n_guns_involved             0
# participant_age             0
# participant_age_group       0
# participant_gender          0
# participant_status          0
# participant_type            0
# state_house_district        0
# state_senate_district       0
# dtype: int64

# %% [markdown]
# ## 4c. Duplicates

# %%
#Creating hecking for duplicates
df_dups = df_guns[df_guns.duplicated()]

# %%
#Viewing df_dups
df_dups
# Out:
# Empty DataFrame
# Columns: [incident_id, date, state, city_or_county, n_killed, n_injured, congressional_district, gun_type, incident_characteristics, n_guns_involved, participant_age, participant_age_group, participant_gender, participant_status, participant_type, state_house_district, state_senate_district]
# Index: []

# %% [markdown]
# No duplicates found

# %%
#Checking shape of cleaned dataframe
df_guns.shape
# Out:
# (239677, 17)

# %% [markdown]
# # 5. Exporting Cleaned Dataframe

# %%
#Exporting updated dataframe
df_guns.to_csv(os.path.join(path, '02 Data','Prepared Data', 'guns_clean.csv'))
